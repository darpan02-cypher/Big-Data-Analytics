# %% [markdown]
# <a href="https://colab.research.google.com/github/darpan02-cypher/Big-Data-Analytics/blob/main/dataset_profile_report/1_data_split_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.0/679.0 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=2c7592e8ee3ddf5d5664f9a30bc85f76b05d9312f9f90fdac8b7169ed0cf8739
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
# ...

# %% [markdown]
# ydata-profiling: This cell installs the ydata-profiling library, which is used for generating detailed reports about a dataset.

# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# GLOBAL VAR
PATH = './'
TRAIN_FRAC = 0.80
RND_STATE = 123

# %%
# READ DATA
dataset = pd.read_csv(PATH+'all_data.csv')
dataset.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2        2.0         1   24      2      2     -1     -1
# 1      90000    2        2.0         2   34      0      0      0      0
# 2      50000    2        2.0         1   37      0      0      0      0
# 3      50000    1        2.0         1   57     -1      0     -1      0
# 4      50000    1        1.0         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
# SPLIT DATA
df = dataset.sample(frac=TRAIN_FRAC, random_state=RND_STATE)
df_unseen = dataset.drop(df.index)

df.reset_index(inplace=True, drop=True)
df_unseen.reset_index(inplace=True, drop=True)

print('Data for Modeling: ' + str(df.shape))
print('Unseen Data For Predictions ' + str(df_unseen.shape))
# Out:
# Data for Modeling: (19200, 24)
# Unseen Data For Predictions (4800, 24)

# %%
# SAVE DATASETS
df.to_csv(PATH+'data_training.csv', index=False)
df_unseen.to_csv(PATH+'data_testing.csv', index=False)

# %%
# PROFILE TRAINING DATASET
profile = ProfileReport(df, title="Training Data Exploration Report", explorative=True)
profile.to_file(PATH+"training_data_exploration_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
